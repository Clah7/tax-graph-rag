# %%
import json

# %%
data = json.load(open('../data/processed/articles.json'))
regs = set(a['regulation_id'] for a in data)
refs = sum(len(a['references']) for a in data)
print(f'Total articles: {len(data)}')
print(f'Total regulations: {len(regs)}')
print(f'Total cross-references: {refs}')
# Out:
# Total articles: 80354
# Total regulations: 1731
# Total cross-references: 53123
